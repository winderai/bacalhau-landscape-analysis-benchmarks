# %% [markdown]
# # Average House Price

# %%
# %%writefile AvgPrice.java
# import org.apache.hadoop.conf.Configuration;
# import org.apache.hadoop.fs.Path;
# import org.apache.hadoop.io.Text;
# import org.apache.hadoop.io.DoubleWritable;
# import org.apache.hadoop.mapreduce.Job;
# import org.apache.hadoop.mapreduce.Mapper;
# import org.apache.hadoop.mapreduce.Reducer;
# import org.apache.hadoop.mapreduce.lib.input.FileInputFormat;
# import org.apache.hadoop.mapreduce.lib.output.FileOutputFormat;
# import org.apache.hadoop.util.GenericOptionsParser;
# import org.apache.hadoop.fs.FileSystem;
# import org.apache.hadoop.fs.FileStatus;
# import org.apache.hadoop.fs.FSDataOutputStream;
# import org.apache.hadoop.mapreduce.lib.input.FileSplit;
#
# import java.io.*;
# import java.io.IOException;
# import java.util.*;
# import java.nio.charset.StandardCharsets;
#
#
# public class AvgPrice
# {
#
#     public static class Map extends Mapper<Object, Text, Text, DoubleWritable>
#     {
#         public void map(Object key, Text value, Context context) throws IOException, InterruptedException
#         {
#             try
#             {
#                 if(value.toString().contains("Address")) // remove header
#                     return;
#                 else
#                 {
#                     String[] data = value.toString().split(",");
#                     String zipcode = data[3];
#                     DoubleWritable price = new DoubleWritable(Double.parseDouble(data[4]));
#
#                     context.write(new Text(zipcode), price);
#                 }
#             }
#             catch (Exception e)
#             {
#                 e.printStackTrace();
#             }
#         }
#     }
#
#     public static class Reduce extends Reducer<Text, DoubleWritable, Text, DoubleWritable>
#     {
#         public void reduce(Text key, Iterable<DoubleWritable> values, Context context) throws IOException, InterruptedException
#         {
#             double sum = 0;
#             int num_of_prices = 0;
#
#             for(DoubleWritable value : values)
#             {
#                 sum += value.get();
#                 num_of_prices++;
#             }
#
#             context.write(key, new DoubleWritable((double) sum / num_of_prices));
#         }
#     }
#
#
#     public static void main(String[] args) throws Exception
#     {
#         // set the paths of the input and output directories in the HDFS
#         Path input_dir = new Path("../data");
#         Path output_dir = new Path("average_prices");
#
#         // in case the output directory already exists, delete it
#         Configuration conf = new Configuration();
#         FileSystem fs = FileSystem.get(conf);
#         if(fs.exists(output_dir))
#             fs.delete(output_dir, true);
#
#         // configure the MapReduce job
#         Job AvgPrice_job = Job.getInstance(conf, "Average Price");
#         AvgPrice_job.setJarByClass(AvgPrice.class);
#         AvgPrice_job.setMapperClass(Map.class);
#         AvgPrice_job.setCombinerClass(Reduce.class);
#         AvgPrice_job.setReducerClass(Reduce.class);
#         AvgPrice_job.setMapOutputKeyClass(Text.class);
#         AvgPrice_job.setMapOutputValueClass(DoubleWritable.class);
#         AvgPrice_job.setOutputKeyClass(Text.class);
#         AvgPrice_job.setOutputValueClass(DoubleWritable.class);
#         FileInputFormat.addInputPath(AvgPrice_job, input_dir);
#         FileOutputFormat.setOutputPath(AvgPrice_job, output_dir);
#         AvgPrice_job.waitForCompletion(true);
#     }
# }
# Out:
# Writing AvgPrice.java

# %%
# %env PATH=/usr/lib/jvm/java-8-openjdk-amd64/bin:/home/ubuntu/bin:/home/ubuntu/bin:/home/ubuntu/miniconda3/bin:/home/ubuntu/miniconda3/condabin:/usr/lib/jvm/java-8-openjdk-amd64/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin
# %env HADOOP_CLASSPATH=/usr/lib/jvm/java-8-openjdk-amd64/lib/tools.jar
# Out:
# env: PATH=/usr/lib/jvm/java-8-openjdk-amd64/bin:/home/ubuntu/bin:/home/ubuntu/bin:/home/ubuntu/miniconda3/bin:/home/ubuntu/miniconda3/condabin:/usr/lib/jvm/java-8-openjdk-amd64/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin
# env: HADOOP_CLASSPATH=/usr/lib/jvm/java-8-openjdk-amd64/lib/tools.jar

# %%
# !echo $HADOOP_HOME
# Out:
# /home/ubuntu/hadoop-3.3.1

# %%
# !$HADOOP_HOME/bin/hadoop com.sun.tools.javac.Main AvgPrice.java

# %%
# !jar cf AvgPrice.jar AvgPrice*.class

# %%
# !$HADOOP_HOME/bin/hadoop jar AvgPrice.jar AvgPrice
# Out:
# head: cannot open '10' for reading: No such file or directory
# 2022-03-21 10:40:34,591 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2022-03-21 10:40:34,673 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2022-03-21 10:40:34,673 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2022-03-21 10:40:34,733 WARN mapreduce.JobResourceUploader: Hadoop command-line option parsing not performed. Implement the Tool interface and execute your application with ToolRunner to remedy this.
# 2022-03-21 10:40:34,789 INFO input.FileInputFormat: Total input files to process : 1
# 2022-03-21 10:40:34,814 INFO mapreduce.JobSubmitter: number of splits:1
# 2022-03-21 10:40:34,943 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1481753162_0001
# 2022-03-21 10:40:34,943 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2022-03-21 10:40:35,054 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2022-03-21 10:40:35,055 INFO mapreduce.Job: Running job: job_local1481753162_0001
# 2022-03-21 10:40:35,060 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2022-03-21 10:40:35,066 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2022-03-21 10:40:35,066 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2022-03-21 10:40:35,066 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter
# 2022-03-21 10:40:35,095 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2022-03-21 10:40:35,095 INFO mapred.LocalJobRunner: Starting task: attempt_local1481753162_0001_m_000000_0
# 2022-03-21 10:40:35,113 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2022-03-21 10:40:35,113 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2022-03-21 10:40:35,128 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2022-03-21 10:40:35,131 INFO mapred.MapTask: Processing split: file:/home/ubuntu/sample-code-benchmark/sample-code/average-house-price/data/address_book.csv:0+932
# 2022-03-21 10:40:35,208 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2022-03-21 10:40:35,208 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2022-03-21 10:40:35,208 INFO mapred.MapTask: soft limit at 83886080
# 2022-03-21 10:40:35,208 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2022-03-21 10:40:35,208 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2022-03-21 10:40:35,212 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2022-03-21 10:40:35,227 INFO mapred.LocalJobRunner:
# 2022-03-21 10:40:35,227 INFO mapred.MapTask: Starting flush of map output
# 2022-03-21 10:40:35,227 INFO mapred.MapTask: Spilling map output
# 2022-03-21 10:40:35,227 INFO mapred.MapTask: bufstart = 0; bufend = 280; bufvoid = 104857600
# 2022-03-21 10:40:35,227 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214320(104857280); length = 77/6553600
# 2022-03-21 10:40:35,238 INFO mapred.MapTask: Finished spill 0
# 2022-03-21 10:40:35,245 INFO mapred.Task: Task:attempt_local1481753162_0001_m_000000_0 is done. And is in the process of committing
# 2022-03-21 10:40:35,247 INFO mapred.LocalJobRunner: map
# 2022-03-21 10:40:35,247 INFO mapred.Task: Task 'attempt_local1481753162_0001_m_000000_0' done.
# 2022-03-21 10:40:35,253 INFO mapred.Task: Final Counters for attempt_local1481753162_0001_m_000000_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=4292
# 		FILE: Number of bytes written=635194
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=21
# 		Map output records=20
# 		Map output bytes=280
# 		Map output materialized bytes=86
# 		Input split bytes=158
# 		Combine input records=20
# 		Combine output records=5
# 		Spilled Records=5
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=265814016
# 	File Input Format Counters
# 		Bytes Read=932
# 2022-03-21 10:40:35,254 INFO mapred.LocalJobRunner: Finishing task: attempt_local1481753162_0001_m_000000_0
# 2022-03-21 10:40:35,254 INFO mapred.LocalJobRunner: map task executor complete.
# 2022-03-21 10:40:35,256 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2022-03-21 10:40:35,257 INFO mapred.LocalJobRunner: Starting task: attempt_local1481753162_0001_r_000000_0
# 2022-03-21 10:40:35,262 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2022-03-21 10:40:35,262 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2022-03-21 10:40:35,262 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2022-03-21 10:40:35,264 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@5e6d6442
# 2022-03-21 10:40:35,266 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2022-03-21 10:40:35,279 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=1297350656, maxSingleShuffleLimit=324337664, mergeThreshold=856251456, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2022-03-21 10:40:35,289 INFO reduce.EventFetcher: attempt_local1481753162_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2022-03-21 10:40:35,310 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1481753162_0001_m_000000_0 decomp: 82 len: 86 to MEMORY
# 2022-03-21 10:40:35,312 INFO reduce.InMemoryMapOutput: Read 82 bytes from map-output for attempt_local1481753162_0001_m_000000_0
# 2022-03-21 10:40:35,313 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 82, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->82
# 2022-03-21 10:40:35,314 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2022-03-21 10:40:35,315 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2022-03-21 10:40:35,315 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2022-03-21 10:40:35,320 INFO mapred.Merger: Merging 1 sorted segments
# 2022-03-21 10:40:35,323 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 74 bytes
# 2022-03-21 10:40:35,323 INFO reduce.MergeManagerImpl: Merged 1 segments, 82 bytes to disk to satisfy reduce memory limit
# 2022-03-21 10:40:35,324 INFO reduce.MergeManagerImpl: Merging 1 files, 86 bytes from disk
# 2022-03-21 10:40:35,324 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2022-03-21 10:40:35,325 INFO mapred.Merger: Merging 1 sorted segments
# 2022-03-21 10:40:35,326 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 74 bytes
# 2022-03-21 10:40:35,327 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2022-03-21 10:40:35,332 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2022-03-21 10:40:35,335 INFO mapred.Task: Task:attempt_local1481753162_0001_r_000000_0 is done. And is in the process of committing
# 2022-03-21 10:40:35,338 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2022-03-21 10:40:35,339 INFO mapred.Task: Task attempt_local1481753162_0001_r_000000_0 is allowed to commit now
# 2022-03-21 10:40:35,340 INFO output.FileOutputCommitter: Saved output of task 'attempt_local1481753162_0001_r_000000_0' to file:/home/ubuntu/sample-code-benchmark/sample-code/average-house-price/hadoop/average_prices
# 2022-03-21 10:40:35,341 INFO mapred.LocalJobRunner: reduce > reduce
# 2022-03-21 10:40:35,342 INFO mapred.Task: Task 'attempt_local1481753162_0001_r_000000_0' done.
# 2022-03-21 10:40:35,342 INFO mapred.Task: Final Counters for attempt_local1481753162_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=4496
# 		FILE: Number of bytes written=635363
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=5
# 		Reduce shuffle bytes=86
# 		Reduce input records=5
# 		Reduce output records=5
# 		Spilled Records=5
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=265814016
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=83
# 2022-03-21 10:40:35,343 INFO mapred.LocalJobRunner: Finishing task: attempt_local1481753162_0001_r_000000_0
# 2022-03-21 10:40:35,343 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2022-03-21 10:40:36,059 INFO mapreduce.Job: Job job_local1481753162_0001 running in uber mode : false
# 2022-03-21 10:40:36,060 INFO mapreduce.Job:  map 100% reduce 100%
# 2022-03-21 10:40:36,061 INFO mapreduce.Job: Job job_local1481753162_0001 completed successfully
# 2022-03-21 10:40:36,068 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=8788
# 		FILE: Number of bytes written=1270557
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=21
# 		Map output records=20
# 		Map output bytes=280
# 		Map output materialized bytes=86
# 		Input split bytes=158
# 		Combine input records=20
# 		Combine output records=5
# 		Reduce input groups=5
# 		Reduce shuffle bytes=86
# 		Reduce input records=5
# 		Reduce output records=5
# 		Spilled Records=10
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=531628032
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=932
# 	File Output Format Counters
# 		Bytes Written=83

# %%
# !$HADOOP_HOME/bin/hadoop fs -cat average_prices/part-r-00000
# Out:
# 19044	30580.25
# 21076	27875.0
# 28202	44750.0
# 60173	43300.0
# 90670	56277.5
